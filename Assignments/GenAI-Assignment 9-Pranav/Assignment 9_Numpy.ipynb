# %%
import numpy as np

# %% [markdown]
# ## Task 1: Creating Numpy Arrays

# %%
one_D_array = np.arange(1,11)
print(one_D_array.shape)
print(one_D_array.dtype)
# Out:
# (10,)
# int64

# %%
two_D_array = np.arange(1,10).reshape(3,3)
print(two_D_array.shape)
print(two_D_array.dtype)
# Out:
# (3, 3)
# int64

# %%
array_data = np.array([10, 20, 30, 40, 50])
print(array_data.shape)
print(array_data.dtype)
# Out:
# (5,)
# int64

# %% [markdown]
# ## Task 2: Important Mathematical Operations

# %%
A = np.array([10,20,30,40,50])
B = np.array([1,2,3,4,5])
print("Additon of A and B is:", A + B)
print("Subtraction of A and B is:", A - B)
print("Multiplication of A and B is:", A * B)
print("Division of A and B is:", (A / B).astype(int))
print("Square of A is:", A ** 2)
# Out:
# Additon of A and B is: [11 22 33 44 55]
# Subtraction of A and B is: [ 9 18 27 36 45]
# Multiplication of A and B is: [ 10  40  90 160 250]
# Division of A and B is: [10 10 10 10 10]
# Square of A is: [ 100  400  900 1600 2500]

# %% [markdown]
# ## Task 3: Important Nummpy Mathematical Formaulas

# %%
values = np.array([2,4,6,8,10])
print("Square Root of element is:", np.sqrt(values))
print("Exponential of element is:", np.exp(values))
print("Logarithm of element is:", np.log(values))
print("Sum of all elements is:", np.sum(values))
print("Cumulative sum of all elements is:", np.cumsum(values))
# Out:
# Square Root of element is: [1.41421356 2.         2.44948974 2.82842712 3.16227766]
# Exponential of element is: [7.38905610e+00 5.45981500e+01 4.03428793e+02 2.98095799e+03
#  2.20264658e+04]
# Logarithm of element is: [0.69314718 1.38629436 1.79175947 2.07944154 2.30258509]
# Sum of all elements is: 30
# Cumulative sum of all elements is: [ 2  6 12 20 30]
