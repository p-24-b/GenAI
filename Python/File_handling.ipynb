# %% [markdown]
# # File Handling in Python

# %% [markdown]
# ### Reading from a file

# %%
filename = 'file_handling.txt'
file = open(filename, 'r')

# %%
file_content = file.read()
print(file_content)
file.close()
# Out:
# Hi this is Pranav Bajpai here.
# This file has been created as a part of file reading lectures of Python as a pre-requisite.

# %% [markdown]
# ### Writing into a file
