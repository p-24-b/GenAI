# %% [markdown]
# ## OS Library

# %%
import os

# %%
## getcwd()
filepath = os.getcwd()
print("Current working directory:", filepath)
# Out:
# Current working directory: c:\Users\p.a.bajpai\GenAI\Python

# %%
## listdir()
dir_contents = os.listdir("c:/Users/p.a.bajpai/GenAI")
print("Contents of the directory:", dir_contents)
# Out:
# Contents of the directory: ['.git', 'Assignments', 'Python', 'README.md', 'test.py']

# %%
filepath = "C:/Users/p.a.bajpai/GenAI/Python/Os_Library.ipynb"
if os.path.exists(filepath):
    print("The file path exists.")
else:
    print("The file path does not exist.")
# Out:
# The file path exists.

# %%
words = filepath.split(sep='/')
words
# Out:
# ['C:', 'Users', 'p.a.bajpai', 'GenAI', 'Python', 'Os_Library.ipynb']
